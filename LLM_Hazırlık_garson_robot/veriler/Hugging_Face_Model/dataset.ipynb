# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from datasets import load_dataset
dataset = load_dataset("bitext/Bitext-restaurants-llm-chatbot-training-dataset")

# %%
# .arrow dosyamızı csv formatına çevirmemiz gerek !!!!
import pandas as pd

# Train split'ini DataFrame'e çevir
df = pd.DataFrame(dataset['train'])
df.to_csv("/home/ali/Desktop/train_data.csv", index=False)
# İlk birkaç satırı görüntüle
print(df.head())
# Out:
#                                          instruction           intent  \
# 0  my plans changed, how could I cancel my fuckin...  cancel_catering
# 1            i want help to cancel my catering order  cancel_catering
# 2             can i cancel ym fucking catering order  cancel_catering
# 3  i got to cacnel my fucking catering order will...  cancel_catering
# 4  my plans changed , would it be possible to can...  cancel_catering
#
#    category     tags                                           response
# 0  CATERING   BCIPWZ  We recognize that circumstances may shift unex...
# 1  CATERING       BQ  We recognize that circumstances may change, an...
# 2  CATERING    BIQWZ  We recognize that unforeseen circumstances may...
# 3  CATERING  BCIPQWZ  We acknowledge that sometimes circumstances re...
# 4  CATERING    BCIPZ  We recognize that circumstances may shift unex...

# %%
df_original = pd.read_csv("train_data.csv")
df_copy = df_original
df_copy.head()
# Out:
#                                          instruction           intent  \
# 0  my plans changed, how could I cancel my fuckin...  cancel_catering
# 1            i want help to cancel my catering order  cancel_catering
# 2             can i cancel ym fucking catering order  cancel_catering
# 3  i got to cacnel my fucking catering order will...  cancel_catering
# 4  my plans changed , would it be possible to can...  cancel_catering
#
#    category     tags                                           response
# 0  CATERING   BCIPWZ  We recognize that circumstances may shift unex...
# 1  CATERING       BQ  We recognize that circumstances may change, an...
# 2  CATERING    BIQWZ  We recognize that unforeseen circumstances may...
# 3  CATERING  BCIPQWZ  We acknowledge that sometimes circumstances re...
# 4  CATERING    BCIPZ  We recognize that circumstances may shift unex...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  30000 non-null  object
#  1   intent       30000 non-null  object
#  2   category     30000 non-null  object
#  3   tags         30000 non-null  object
#  4   response     30000 non-null  object
# dtypes: object(5)
# memory usage: 1.1+ MB

# %%
df_copy.isnull().sum()
# Out:
# instruction    0
# intent         0
# category       0
# tags           0
# response       0
# dtype: int64
